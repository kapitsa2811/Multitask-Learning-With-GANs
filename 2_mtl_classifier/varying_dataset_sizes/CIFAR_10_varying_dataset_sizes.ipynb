# %%
import tensorflow as tf
import numpy as np
import mlp.tf_utils as utils
from mlp.data_providers import AugmentedCIFAR10DataProvider, AugmentedCIFAR100DataProvider, CIFAR100DataProvider, CIFAR10DataProvider
from mlp.image_transforms import random_flip, random_crop, center_crop, random_flip_small
from mlp.Conv_models import ConvModel, TwoTaskConvModel
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

seed = 12345 
rng = np.random.RandomState(seed)

# %%
layer_dims = [3, 64, 128, 256, 512, _]
batch_size = 128

bifurcation_point = 2
joint_loss = False
max_pools = [True, True, False, True]
lrns = []
lrn_alphas = []
batch_norms = [True, True, True, True]
l1 = False
l2 = 5e-4
learning_rates = [2e-4]  
lrn_schedule = []
optimizer_params = [0.9, 0.999]  
activation = tf.nn.relu
dropout = False
epochs = 50
error = 'soft_max_cross_entropy'
image_size = 32  
optimiser = "Adam"  
logs_dir = "tf-log"

# %%
mtl_models = []
b_models_100 = []
b_models_10 = []

for i, ratio in enumerate([1., 0.75, 0.5, 0.25]):
    tf.reset_default_graph()
    model_name = 'sanity_check_' + str(ratio) + "_of_the_data"
    print("MODEL:- " + model_name)
    
    main_train_data = CIFAR100DataProvider(which_set='train',
                                                    batch_size=batch_size, shuffle_order=False)
    main_valid_data = CIFAR100DataProvider(which_set='valid', batch_size=batch_size, shuffle_order=False)

    aux_train_data = CIFAR10DataProvider(which_set='train', batch_size=batch_size, shuffle_order=False)
    aux_valid_data = CIFAR10DataProvider(which_set='valid', batch_size=batch_size, shuffle_order=False)
    
    m_t_idx = utils.sample_data(main_train_data, ratio)
    m_v_idx = utils.sample_data(main_valid_data, ratio)
    _1 = utils.sample_data(aux_train_data, ratio, m_t_idx)
    _2 = utils.sample_data(aux_valid_data, ratio, m_v_idx)
    
    model = TwoTaskConvModel(conv_layer_dims=layer_dims, main_train_data=main_train_data, main_valid_data=main_valid_data,
                         aux_train_data=aux_train_data, aux_valid_data=aux_valid_data, L1=l1, L2=l2,
                         batch_size=batch_size, learning_rates=learning_rates, learning_rate_schedule=lrn_schedule,
                         optimiser=optimiser, max_pools=max_pools, lin_response_norms=lrns,
                         lin_response_alphas=lrn_alphas, batch_norms=batch_norms, bifurcation_point=bifurcation_point,
                         optimiser_params=optimizer_params, activation=activation, dropout=dropout,
                         epochs=epochs, error=error, input_image_size=image_size, name=model_name, joint_loss=joint_loss)
    
    model.create_network()
    model.initialize_network(logs_dir)
    model.train_model()

    mtl_models.append(model)
    
    tf.reset_default_graph()
    model_name = 'baseline_100_with_' + str(ratio) + "_of_the_data"
    print("MODEL:- " + model_name)
    
    train_data = CIFAR100DataProvider(which_set='train', batch_size=batch_size)
    valid_data = CIFAR100DataProvider(which_set='valid', batch_size=batch_size)
    
    # update baseline data providers to have same samples 
    _3 = utils.sample_data(train_data, ratio, m_t_idx)
    _4 = utils.sample_data(valid_data, ratio, m_v_idx)
    
    model_b_100 = ConvModel(conv_layer_dims=layer_dims, train_data=train_data, valid_data=valid_data,
                 batch_size=batch_size, learning_rates=learning_rates, learning_rate_schedule=[],
                 optimiser=optimiser, L1=l1, L2=l2,
                 max_pools=max_pools, lin_response_norms=lrns, lin_response_alphas=lrn_alphas, batch_norms=batch_norms,
                 optimiser_params=optimizer_params, activation=activation, dropout=dropout,
                 epochs=epochs, error=error, input_image_size=image_size, name=model_name)
    model_b_100.create_network()
    model_b_100.initialize_network(logs_dir)
    model_b_100.train_model()
    
    b_models_100.append(model_b_100)
    
    tf.reset_default_graph()
    model_name = 'baseline_10_with_' + str(ratio) + "_of_the_data"
    print("MODEL:- " + model_name)
    
    train_data = CIFAR10DataProvider(which_set='train', batch_size=batch_size)
    valid_data = CIFAR10DataProvider(which_set='valid', batch_size=batch_size)
    
    # update baseline data providers to have same samples 
    _5 = utils.sample_data(train_data, ratio, m_t_idx)
    _6 = utils.sample_data(valid_data, ratio, m_v_idx)
    
    model_b_10 = ConvModel(conv_layer_dims=layer_dims, train_data=train_data, valid_data=valid_data,
                 batch_size=batch_size, learning_rates=learning_rates, learning_rate_schedule=[],
                 optimiser=optimiser, L1=l1, L2=l2,
                 max_pools=max_pools, lin_response_norms=lrns, lin_response_alphas=lrn_alphas, batch_norms=batch_norms,
                 optimiser_params=optimizer_params, activation=activation, dropout=dropout,
                 epochs=epochs, error=error, input_image_size=image_size, name=model_name)
    model_b_10.create_network()
    model_b_10.initialize_network(logs_dir)
    model_b_10.train_model()
    
    b_models_10.append(model_b_10)
# Out:
# MODEL:- sanity_check_1.0_of_the_data
# Setting up model...
# sanity_check_1.0_of_the_data_conv_model/W_0 SHARED
# sanity_check_1.0_of_the_data_conv_model/b_0 SHARED
# sanity_check_1.0_of_the_data_conv_model/BatchNorm/beta SHARED
# sanity_check_1.0_of_the_data_conv_model/W_1 SHARED
# sanity_check_1.0_of_the_data_conv_model/b_1 SHARED
# sanity_check_1.0_of_the_data_conv_model/BatchNorm_1/beta SHARED
# sanity_check_1.0_of_the_data_conv_model/W_2_main NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/W_2_aux NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/b_2_main NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/b_2_aux NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/main_2_bn/beta NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/aux_2_bn/beta NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/W_3_main NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/W_3_aux NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/b_3_main NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/b_3_aux NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/main_3_bn/beta NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/aux_3_bn/beta NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/W_main_pred NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/W_aux_pred NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/b_main_pred NOT SHARED
# sanity_check_1.0_of_the_data_conv_model/b_aux_pred NOT SHARED
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 3655.69374704
# MODEL:- baseline_100_with_1.0_of_the_data
# Setting up model...
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 835.578512907
# MODEL:- baseline_10_with_1.0_of_the_data
# Setting up model...
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 851.463562012
# MODEL:- sanity_check_0.75_of_the_data
# Setting up model...
# sanity_check_0.75_of_the_data_conv_model/W_0 SHARED
# sanity_check_0.75_of_the_data_conv_model/b_0 SHARED
# sanity_check_0.75_of_the_data_conv_model/BatchNorm/beta SHARED
# sanity_check_0.75_of_the_data_conv_model/W_1 SHARED
# sanity_check_0.75_of_the_data_conv_model/b_1 SHARED
# sanity_check_0.75_of_the_data_conv_model/BatchNorm_1/beta SHARED
# sanity_check_0.75_of_the_data_conv_model/W_2_main NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/W_2_aux NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/b_2_main NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/b_2_aux NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/main_2_bn/beta NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/aux_2_bn/beta NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/W_3_main NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/W_3_aux NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/b_3_main NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/b_3_aux NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/main_3_bn/beta NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/aux_3_bn/beta NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/W_main_pred NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/W_aux_pred NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/b_main_pred NOT SHARED
# sanity_check_0.75_of_the_data_conv_model/b_aux_pred NOT SHARED
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 2816.23303795
# MODEL:- baseline_100_with_0.75_of_the_data
# Setting up model...
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 667.341325998
# MODEL:- baseline_10_with_0.75_of_the_data
# Setting up model...
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 681.645955086
# MODEL:- sanity_check_0.5_of_the_data
# Setting up model...
# sanity_check_0.5_of_the_data_conv_model/W_0 SHARED
# sanity_check_0.5_of_the_data_conv_model/b_0 SHARED
# sanity_check_0.5_of_the_data_conv_model/BatchNorm/beta SHARED
# sanity_check_0.5_of_the_data_conv_model/W_1 SHARED
# sanity_check_0.5_of_the_data_conv_model/b_1 SHARED
# sanity_check_0.5_of_the_data_conv_model/BatchNorm_1/beta SHARED
# sanity_check_0.5_of_the_data_conv_model/W_2_main NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/W_2_aux NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/b_2_main NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/b_2_aux NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/main_2_bn/beta NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/aux_2_bn/beta NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/W_3_main NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/W_3_aux NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/b_3_main NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/b_3_aux NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/main_3_bn/beta NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/aux_3_bn/beta NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/W_main_pred NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/W_aux_pred NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/b_main_pred NOT SHARED
# sanity_check_0.5_of_the_data_conv_model/b_aux_pred NOT SHARED
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 1936.5924921
# MODEL:- baseline_100_with_0.5_of_the_data
# Setting up model...
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 490.000572205
# MODEL:- baseline_10_with_0.5_of_the_data
# Setting up model...
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 628.63499403
# MODEL:- sanity_check_0.25_of_the_data
# Setting up model...
# sanity_check_0.25_of_the_data_conv_model/W_0 SHARED
# sanity_check_0.25_of_the_data_conv_model/b_0 SHARED
# sanity_check_0.25_of_the_data_conv_model/BatchNorm/beta SHARED
# sanity_check_0.25_of_the_data_conv_model/W_1 SHARED
# sanity_check_0.25_of_the_data_conv_model/b_1 SHARED
# sanity_check_0.25_of_the_data_conv_model/BatchNorm_1/beta SHARED
# sanity_check_0.25_of_the_data_conv_model/W_2_main NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/W_2_aux NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/b_2_main NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/b_2_aux NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/main_2_bn/beta NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/aux_2_bn/beta NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/W_3_main NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/W_3_aux NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/b_3_main NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/b_3_aux NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/main_3_bn/beta NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/aux_3_bn/beta NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/W_main_pred NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/W_aux_pred NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/b_main_pred NOT SHARED
# sanity_check_0.25_of_the_data_conv_model/b_aux_pred NOT SHARED
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 1160.52041101
# MODEL:- baseline_100_with_0.25_of_the_data
# Setting up model...
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 389.02268815
# MODEL:- baseline_10_with_0.25_of_the_data
# Setting up model...
# Initializing network...
# Training model...
# Epoch finished:  1
# Epoch finished:  2
# Epoch finished:  3
# Epoch finished:  4
# Epoch finished:  5
# Epoch finished:  6
# Epoch finished:  7
# Epoch finished:  8
# Epoch finished:  9
# Epoch finished:  10
# Epoch finished:  11
# Epoch finished:  12
# Epoch finished:  13
# Epoch finished:  14
# Epoch finished:  15
# Epoch finished:  16
# Epoch finished:  17
# Epoch finished:  18
# Epoch finished:  19
# Epoch finished:  20
# Epoch finished:  21
# Epoch finished:  22
# Epoch finished:  23
# Epoch finished:  24
# Epoch finished:  25
# Epoch finished:  26
# Epoch finished:  27
# Epoch finished:  28
# Epoch finished:  29
# Epoch finished:  30
# Epoch finished:  31
# Epoch finished:  32
# Epoch finished:  33
# Epoch finished:  34
# Epoch finished:  35
# Epoch finished:  36
# Epoch finished:  37
# Epoch finished:  38
# Epoch finished:  39
# Epoch finished:  40
# Epoch finished:  41
# Epoch finished:  42
# Epoch finished:  43
# Epoch finished:  44
# Epoch finished:  45
# Epoch finished:  46
# Epoch finished:  47
# Epoch finished:  48
# Epoch finished:  49
# Epoch finished:  50
# Time taken: 391.573915958

# %%
b = b_models[0]
for v in b.train_variables:
    print(v.op.name)
print( "  -----------   ")
m = mtl_models[0]
for v in m.train_variables:
    print(v.op.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ee53cf6a8d9d> in <module>()
# ----> 1 b = b_models[0]
#       2 for v in b.train_variables:
#       3     print(v.op.name)
#       4 print( "  -----------   ")
#       5 m = mtl_models[0]
#
# NameError: name 'b_models' is not defined
